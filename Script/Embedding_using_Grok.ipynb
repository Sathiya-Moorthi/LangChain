# %% [markdown]
# Generate Text Embeddings Using Groq

# %%
# %pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from groq import Groq

client = Groq(api_key="your_api_key")

text_input = "LangChain is a framework for building applications powered by LLMs."

response = client.embeddings.create(
    model="text-embedding-3-large",
    input=text_input
)

embedding_vector = response.data[0].embedding

print("Embedding length:", len(embedding_vector))
print("First 10 values:", embedding_vector[:10])
